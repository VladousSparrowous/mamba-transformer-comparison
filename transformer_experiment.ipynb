# %%
# !git clone https://github.com/VladousSparrowous/mamba-transformer-comparison.git
# Out:
# Cloning into 'mamba-transformer-comparison'...
# remote: Enumerating objects: 327, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 327 (delta 22), reused 30 (delta 14), pack-reused 284 (from 1)
# Receiving objects: 100% (327/327), 90.60 KiB | 583.00 KiB/s, done.
# Resolving deltas: 100% (211/211), done.

# %%
# !pip install mamba-ssm --no-build-isolation
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.4/216.4 kB 9.1 MB/s eta 0:00:00
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 MB 45.4 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 76.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 338.7/338.7 kB 25.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 MB 21.2 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 98.4 MB/s eta 0:00:00:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.3/29.3 MB 69.0 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.8/897.8 kB 48.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.4/323.4 kB 26.4 MB/s eta 0:00:00
# ...

# %%
import shutil
shutil.rmtree('/kaggle/working/mamba-transformer-comparison')
# %cd /kaggle/working/
# Out:
# /kaggle/working

# %%
# %cd mamba-transformer-comparison
# Out:
# /kaggle/working/mamba-transformer-comparison

# %% [markdown]
# # Эксперименты

# %%
# !python transformer/experiment_transformer.py
# Out:
# ...
# Experiment: Transformer without pos_emb with Self-Pretraining (SPT)
# ...
# Using device: cuda
# GPU Memory: 14.56 GB
# Loading datasets...
# ...
# Processing test set: 100%|██████████████| 25000/25000 [00:11<00:00, 2167.73it/s]
# Initializing Transformer model...
# Model parameters: 155,520
# Model size: 0.59 MB (float32)
# Starting Self-Pretraining (SPT)...
# SPT Epoch 1: 100%|███████████████| 1563/1563 [05:25<00:00,  4.80it/s, loss=1.39]
# SPT Epoch 1: Avg Loss = 2.0633
# SPT Epoch 2: 100%|███████████████| 1563/1563 [05:24<00:00,  4.82it/s, loss=1.29]
# SPT Epoch 2: Avg Loss = 1.3121
# SPT Epoch 3: 100%|███████████████| 1563/1563 [05:25<00:00,  4.79it/s, loss=1.24]
# SPT Epoch 3: Avg Loss = 1.1845
# SPT Epoch 4: 100%|███████████████| 1563/1563 [05:26<00:00,  4.79it/s, loss=1.15]
# SPT Epoch 4: Avg Loss = 1.1195
# SPT Epoch 5: 100%|███████████████| 1563/1563 [05:25<00:00,  4.80it/s, loss=1.15]
# SPT Epoch 5: Avg Loss = 1.0770
# Starting Fine-tuning...
# ...
